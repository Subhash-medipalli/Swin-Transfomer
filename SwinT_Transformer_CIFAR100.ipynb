# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#############################RandomAgumentation##############################

import random
import PIL, PIL.ImageOps, PIL.ImageEnhance, PIL.ImageDraw
import numpy as np
import torch
from PIL import Image

# Define all augmentations
def ShearX(img, v):
    assert -0.3 <= v <= 0.3
    if random.random() > 0.5:
        v = -v
    return img.transform(img.size, PIL.Image.AFFINE, (1, v, 0, 0, 1, 0))

def ShearY(img, v):
    assert -0.3 <= v <= 0.3
    if random.random() > 0.5:
        v = -v
    return img.transform(img.size, PIL.Image.AFFINE, (1, 0, 0, v, 1, 0))

def TranslateX(img, v):
    assert -0.45 <= v <= 0.45
    if random.random() > 0.5:
        v = -v
    v = v * img.size[0]
    return img.transform(img.size, PIL.Image.AFFINE, (1, 0, v, 0, 1, 0))

def TranslateY(img, v):
    assert -0.45 <= v <= 0.45
    if random.random() > 0.5:
        v = -v
    v = v * img.size[1]
    return img.transform(img.size, PIL.Image.AFFINE, (1, 0, 0, 0, 1, v))

def Rotate(img, v):
    assert -30 <= v <= 30
    if random.random() > 0.5:
        v = -v
    return img.rotate(v)

def AutoContrast(img, _):
    return PIL.ImageOps.autocontrast(img)

def Invert(img, _):
    return PIL.ImageOps.invert(img)

def Equalize(img, _):
    return PIL.ImageOps.equalize(img)

def Flip(img, _):
    return PIL.ImageOps.mirror(img)

def Solarize(img, v):
    assert 0 <= v <= 256
    return PIL.ImageOps.solarize(img, v)

def Posterize(img, v):
    v = int(v)
    v = max(1, v)
    return PIL.ImageOps.posterize(img, v)

def Contrast(img, v):
    assert 0.1 <= v <= 1.9
    return PIL.ImageEnhance.Contrast(img).enhance(v)

def Color(img, v):
    assert 0.1 <= v <= 1.9
    return PIL.ImageEnhance.Color(img).enhance(v)

def Brightness(img, v):
    assert 0.1 <= v <= 1.9
    return PIL.ImageEnhance.Brightness(img).enhance(v)

def Sharpness(img, v):
    assert 0.1 <= v <= 1.9
    return PIL.ImageEnhance.Sharpness(img).enhance(v)

def Cutout(img, v):
    assert 0.0 <= v <= 0.2
    if v <= 0.:
        return img
    v = v * img.size[0]
    return CutoutAbs(img, v)

def CutoutAbs(img, v):
    w, h = img.size
    x0 = np.random.uniform(w)
    y0 = np.random.uniform(h)
    x0 = int(max(0, x0 - v / 2.))
    y0 = int(max(0, y0 - v / 2.))
    x1 = min(w, x0 + v)
    y1 = min(h, y0 + v)
    xy = (x0, y0, x1, y1)
    color = (125, 123, 114)
    img = img.copy()
    PIL.ImageDraw.Draw(img).rectangle(xy, color)
    return img

def augment_list():
    return [
        (AutoContrast, 0, 1),
        (Equalize, 0, 1),
        (Invert, 0, 1),
        (Rotate, 0, 30),
        (Posterize, 0, 4),
        (Solarize, 0, 256),
        (Color, 0.1, 1.9),
        (Contrast, 0.1, 1.9),
        (Brightness, 0.1, 1.9),
        (Sharpness, 0.1, 1.9),
        (ShearX, 0., 0.3),
        (ShearY, 0., 0.3),
        (TranslateX, 0., 0.45),
        (TranslateY, 0., 0.45),
        (Cutout, 0., 0.2)
    ]

class RandAugment:
    def __init__(self, n, m):
        self.n = n
        self.m = m
        self.augment_list = augment_list()

    def __call__(self, img):
        ops = random.choices(self.augment_list, k=self.n)
        for op, minval, maxval in ops:
            val = (float(self.m) / 30) * float(maxval - minval) + minval
            img = op(img, val)
        return img

# %%
################################# CIFAR-10 and CIFAR-100 dataloader#################################
import torch
import torchvision
import torchvision.transforms as transforms
#from randomaug import RandAugment
import matplotlib.pyplot as plt


def get_loaders_CIFAR10(size, batch_size, aug=True, N=2, M=14):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.Resize(size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    ])

    transform_test = transforms.Compose([
        transforms.Resize(size),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    ])

    if aug:
        transform_train.transforms.insert(0, RandAugment(N, M))

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset, batch_size=batch_size, shuffle=True, num_workers=8
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset, batch_size=100, shuffle=False, num_workers=8
    )

    return trainloader, testloader


def get_loaders_CIFAR100(size, batch_size, aug=True, N=2, M=14):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.Resize(size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
    ])

    transform_test = transforms.Compose([
        transforms.Resize(size),
        transforms.ToTensor(),
        transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
    ])

    if aug:
        transform_train.transforms.insert(0, RandAugment(N, M))

    trainset = torchvision.datasets.CIFAR100(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset, batch_size=batch_size, shuffle=True, num_workers=8
    )

    testset = torchvision.datasets.CIFAR100(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset, batch_size=100, shuffle=False, num_workers=8
    )

    return trainloader, testloader

# %%
################################ Swin Transformer ################################
import torch
from torch import nn, einsum
import numpy as np
from einops import rearrange, repeat


class CyclicShift(nn.Module):
    def __init__(self, displacement):
        super().__init__()
        self.displacement = displacement

    def forward(self, x):
        return torch.roll(x, shifts=(self.displacement, self.displacement), dims=(1, 2))


class Residual(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, **kwargs):
        return self.fn(x, **kwargs) + x


class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn

    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)


class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Linear(hidden_dim, dim),
        )

    def forward(self, x):
        return self.net(x)


def create_mask(window_size, displacement, upper_lower, left_right):
    mask = torch.zeros(window_size ** 2, window_size ** 2)

    if upper_lower:
        mask[-displacement * window_size:, :-displacement * window_size] = float('-inf')
        mask[:-displacement * window_size, -displacement * window_size:] = float('-inf')

    if left_right:
        mask = rearrange(mask, '(h1 w1) (h2 w2) -> h1 w1 h2 w2', h1=window_size, h2=window_size)
        mask[:, -displacement:, :, :-displacement] = float('-inf')
        mask[:, :-displacement, :, -displacement:] = float('-inf')
        mask = rearrange(mask, 'h1 w1 h2 w2 -> (h1 w1) (h2 w2)')

    return mask


def get_relative_distances(window_size):
    indices = torch.tensor(np.array([[x, y] for x in range(window_size) for y in range(window_size)]))
    distances = indices[None, :, :] - indices[:, None, :]
    return distances


class WindowAttention(nn.Module):
    def __init__(self, dim, heads, head_dim, shifted, window_size, relative_pos_embedding):
        super().__init__()
        inner_dim = head_dim * heads

        self.heads = heads
        self.scale = head_dim ** -0.5
        self.window_size = window_size
        self.relative_pos_embedding = relative_pos_embedding
        self.shifted = shifted

        if self.shifted:
            displacement = window_size // 2
            self.cyclic_shift = CyclicShift(-displacement)
            self.cyclic_back_shift = CyclicShift(displacement)
            self.upper_lower_mask = nn.Parameter(create_mask(window_size=window_size, displacement=displacement,
                                                             upper_lower=True, left_right=False), requires_grad=False)
            self.left_right_mask = nn.Parameter(create_mask(window_size=window_size, displacement=displacement,
                                                            upper_lower=False, left_right=True), requires_grad=False)

        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias=False)

        if self.relative_pos_embedding:
            self.relative_indices = get_relative_distances(window_size) + window_size - 1
            self.pos_embedding = nn.Parameter(torch.randn(2 * window_size - 1, 2 * window_size - 1))
        else:
            self.pos_embedding = nn.Parameter(torch.randn(window_size ** 2, window_size ** 2))

        self.to_out = nn.Linear(inner_dim, dim)

    def forward(self, x):
        if self.shifted:
            x = self.cyclic_shift(x)

        b, n_h, n_w, _, h = *x.shape, self.heads

        qkv = self.to_qkv(x).chunk(3, dim=-1)
        nw_h = n_h // self.window_size
        nw_w = n_w // self.window_size

        q, k, v = map(
            lambda t: rearrange(t, 'b (nw_h w_h) (nw_w w_w) (h d) -> b h (nw_h nw_w) (w_h w_w) d',
                                h=h, w_h=self.window_size, w_w=self.window_size), qkv)

        dots = einsum('b h w i d, b h w j d -> b h w i j', q, k) * self.scale

        if self.relative_pos_embedding:
            dots += self.pos_embedding[self.relative_indices[:, :, 0], self.relative_indices[:, :, 1]]
        else:
            dots += self.pos_embedding

        if self.shifted:
            dots[:, :, -nw_w:] += self.upper_lower_mask
            dots[:, :, nw_w - 1::nw_w] += self.left_right_mask

        attn = dots.softmax(dim=-1)

        out = einsum('b h w i j, b h w j d -> b h w i d', attn, v)
        out = rearrange(out, 'b h (nw_h nw_w) (w_h w_w) d -> b (nw_h w_h) (nw_w w_w) (h d)',
                        h=h, w_h=self.window_size, w_w=self.window_size, nw_h=nw_h, nw_w=nw_w)
        out = self.to_out(out)

        if self.shifted:
            out = self.cyclic_back_shift(out)
        return out


class SwinBlock(nn.Module):
    def __init__(self, dim, heads, head_dim, mlp_dim, shifted, window_size, relative_pos_embedding):
        super().__init__()
        self.attention_block = Residual(PreNorm(dim, WindowAttention(dim=dim,
                                                                     heads=heads,
                                                                     head_dim=head_dim,
                                                                     shifted=shifted,
                                                                     window_size=window_size,
                                                                     relative_pos_embedding=relative_pos_embedding)))
        self.mlp_block = Residual(PreNorm(dim, FeedForward(dim=dim, hidden_dim=mlp_dim)))

    def forward(self, x):
        x = self.attention_block(x)
        x = self.mlp_block(x)
        return x


class PatchMerging(nn.Module):
    def __init__(self, in_channels, out_channels, downscaling_factor):
        super().__init__()
        self.downscaling_factor = downscaling_factor
        self.patch_merge = nn.Unfold(kernel_size=downscaling_factor, stride=downscaling_factor, padding=0)
        self.linear = nn.Linear(in_channels * downscaling_factor ** 2, out_channels)

    def forward(self, x):
        b, c, h, w = x.shape
        new_h, new_w = h // self.downscaling_factor, w // self.downscaling_factor
        x = self.patch_merge(x).view(b, -1, new_h, new_w).permute(0, 2, 3, 1)
        x = self.linear(x)
        return x


class StageModule(nn.Module):
    def __init__(self, in_channels, hidden_dimension, layers, downscaling_factor, num_heads, head_dim, window_size,
                 relative_pos_embedding):
        super().__init__()
        assert layers % 2 == 0, 'Stage layers need to be divisible by 2 for regular and shifted block.'

        self.patch_partition = PatchMerging(in_channels=in_channels, out_channels=hidden_dimension,
                                            downscaling_factor=downscaling_factor)

        self.layers = nn.ModuleList([])
        for _ in range(layers // 2):
            self.layers.append(nn.ModuleList([
                SwinBlock(dim=hidden_dimension, heads=num_heads, head_dim=head_dim, mlp_dim=hidden_dimension * 4,
                          shifted=False, window_size=window_size, relative_pos_embedding=relative_pos_embedding),
                SwinBlock(dim=hidden_dimension, heads=num_heads, head_dim=head_dim, mlp_dim=hidden_dimension * 4,
                          shifted=True, window_size=window_size, relative_pos_embedding=relative_pos_embedding),
            ]))

    def forward(self, x):
        x = self.patch_partition(x)
        for regular_block, shifted_block in self.layers:
            x = regular_block(x)
            x = shifted_block(x)
        return x.permute(0, 3, 1, 2)


class SwinTransformer(nn.Module):
    def __init__(self, *, hidden_dim, layers, heads, channels=3, num_classes=1000, head_dim=32, window_size=7,
                 downscaling_factors=(4, 2, 2, 2), relative_pos_embedding=True):
        super().__init__()

        self.stage1 = StageModule(in_channels=channels, hidden_dimension=hidden_dim, layers=layers[0],
                                  downscaling_factor=downscaling_factors[0], num_heads=heads[0], head_dim=head_dim,
                                  window_size=window_size, relative_pos_embedding=relative_pos_embedding)
        self.stage2 = StageModule(in_channels=hidden_dim, hidden_dimension=hidden_dim * 2, layers=layers[1],
                                  downscaling_factor=downscaling_factors[1], num_heads=heads[1], head_dim=head_dim,
                                  window_size=window_size, relative_pos_embedding=relative_pos_embedding)
        self.stage3 = StageModule(in_channels=hidden_dim * 2, hidden_dimension=hidden_dim * 4, layers=layers[2],
                                  downscaling_factor=downscaling_factors[2], num_heads=heads[2], head_dim=head_dim,
                                  window_size=window_size, relative_pos_embedding=relative_pos_embedding)
        self.stage4 = StageModule(in_channels=hidden_dim * 4, hidden_dimension=hidden_dim * 8, layers=layers[3],
                                  downscaling_factor=downscaling_factors[3], num_heads=heads[3], head_dim=head_dim,
                                  window_size=window_size, relative_pos_embedding=relative_pos_embedding)

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(hidden_dim * 8),
            nn.Linear(hidden_dim * 8, num_classes)
        )

    def forward(self, img):
        x = self.stage1(img)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.stage4(x)
        x = x.mean(dim=[2, 3])
        return self.mlp_head(x)


def swin_t(hidden_dim=96, layers=(2, 2, 6, 2), heads=(3, 6, 12, 24), **kwargs):
    return SwinTransformer(hidden_dim=hidden_dim, layers=layers, heads=heads, **kwargs)


def swin_s(hidden_dim=96, layers=(2, 2, 18, 2), heads=(3, 6, 12, 24), **kwargs):
    return SwinTransformer(hidden_dim=hidden_dim, layers=layers, heads=heads, **kwargs)


def swin_b(hidden_dim=128, layers=(2, 2, 18, 2), heads=(4, 8, 16, 32), **kwargs):
    return SwinTransformer(hidden_dim=hidden_dim, layers=layers, heads=heads, **kwargs)


def swin_l(hidden_dim=192, layers=(2, 2, 18, 2), heads=(6, 12, 24, 48), **kwargs):
    return SwinTransformer(hidden_dim=hidden_dim, layers=layers, heads=heads, **kwargs)


# To summarize, your swin_transformer.py defines:
# - SwinTransformer
# - swin_t (tiny)
# - swin_s (small)
# - swin_b (base)
# - swin_l (large)

# It is fully ready!

# Example (for your reference):
# from swin_transformer import swin_t

# model = swin_t(
#     hidden_dim=96,
#     layers=(2, 2, 6, 2),
#     heads=(3, 6, 12, 24),
#     channels=3,
#     num_classes=10,
#     head_dim=32,
#     window_size=4,
#     downscaling_factors=(2, 2, 2, 1),
#     relative_pos_embedding=True
# )

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import os
import numpy as np
import matplotlib.pyplot as plt

#from swin_transformer import swin_t
#from custom_loader import get_loaders_CIFAR100  # Update this to your actual data loader file
#from custom_plotting import plot_training  # Or replace with your local function as defined below


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def train(epoch, net, trainloader, criterion, optimizer, scaler, use_amp, device):
    print(f'\nEpoch: {epoch}')
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)

        with torch.cuda.amp.autocast(enabled=use_amp):
            outputs = net(inputs)
            loss = criterion(outputs, targets)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100. * correct / total
    print(f'Train Loss: {train_loss / len(trainloader):.4f} | Train Acc: {acc:.2f}%')
    return train_loss / len(trainloader), acc


def test(epoch, net, testloader, criterion, optimizer, scaler, best_acc, args, device):
    net.eval()
    test_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    acc = 100. * correct / total
    print(f'Test Loss: {test_loss / len(testloader):.4f} | Test Acc: {acc:.2f}%')

    if acc > best_acc:
        print('Saving checkpoint..')
        state = {
            'model': net.state_dict(),
            'acc': acc,
            'epoch': epoch,
            'optimizer': optimizer.state_dict(),
            'scaler': scaler.state_dict()
        }
        os.makedirs('checkpoint', exist_ok=True)
        torch.save(state, f'./checkpoint/{args.net}-{args.patch}-ckpt.t7')
        best_acc = acc

    return test_loss, acc, best_acc

def plot_accuracy(train_acc, val_acc):
    train_acc = [x.item() if torch.is_tensor(x) else x for x in train_acc]
    val_acc = [x.item() if torch.is_tensor(x) else x for x in val_acc]
    plt.figure(figsize=(10, 6))
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.title('Train vs Test Accuracy')
    plt.legend()
    plt.grid(True)
    plt.savefig('accuracy_plot.png')
    plt.show()


def plot_loss(train_loss, val_loss):
    train_loss = [x.item() if torch.is_tensor(x) else x for x in train_loss]
    val_loss = [x.item() if torch.is_tensor(x) else x for x in val_loss]
    plt.figure(figsize=(10, 6))
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Train vs Test Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('loss_plot.png')
    plt.show()


def plot_training(train_losses, test_losses, test_accuracies):
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, test_losses, label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Train & Test Loss By Epoch')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracies, label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.title('Test Accuracy By Epoch')
    plt.legend()

    plt.tight_layout()
    plt.show()


def visualize_predictions(net, testloader, classes, num_samples=5, epoch=0, device='cuda'):
    net.eval()
    all_images = []
    all_labels = []

    for images, labels in testloader:
        all_images.append(images)
        all_labels.append(labels)

    all_images = torch.cat(all_images, dim=0)
    all_labels = torch.cat(all_labels, dim=0)

    idx = np.random.choice(len(all_images), num_samples, replace=False)
    images = all_images[idx]
    labels = all_labels[idx]

    images = images.to(device)
    with torch.no_grad():
        outputs = net(images)
        _, preds = outputs.max(1)

    images = images.cpu()
    preds = preds.cpu()
    labels = labels.cpu()

    fig, axes = plt.subplots(1, num_samples, figsize=(num_samples * 2, 2))
    for i in range(num_samples):
        img = images[i]
        img = img.permute(1, 2, 0)
        img = img * torch.tensor([0.2023, 0.1994, 0.2010]) + torch.tensor([0.4914, 0.4822, 0.4465])
        img = img.numpy()
        img = np.clip(img, 0, 1)
        axes[i].imshow(img)
        axes[i].axis('off')
        axes[i].set_title(f"P: {classes[preds[i]]}\nT: {classes[labels[i]]}", fontsize=6)

    os.makedirs('sample_predictions', exist_ok=True)
    save_path = f'sample_predictions/epoch_{epoch}.png'
    plt.tight_layout(pad=0.1)
    plt.savefig(save_path, dpi=600, bbox_inches='tight')
    plt.close()
    print(f"Saved sample predictions at: {save_path}")


def main():
    args = type('', (), {})()
    args.dataset = 'CIFAR100'
    args.dataset_classes = 100
    args.lr = 1e-4
    args.opt = 'adam'
    args.resume = True
    args.noaug = False
    args.noamp = False
    args.dp = True
    args.net = 'swin'
    args.heads = 6
    args.layers = 12
    args.bs = 64
    args.size = 32
    args.n_epochs = 200  # or however many you want
    args.patch = 4
    args.dimhead = 420

    best_acc = 0
    start_epoch = 0
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    # ✅ Load CIFAR-100 data and class names
    trainloader, testloader = get_loaders_CIFAR100(args.size, args.bs, aug=not args.noaug)
    classes = torchvision.datasets.CIFAR100(root='./data', train=False).classes

    net = swin_t(
        hidden_dim=96,
        layers=(2, 2, 6, 2),
        heads=(3, 6, 12, 24),
        channels=3,
        num_classes=args.dataset_classes,
        head_dim=args.dimhead,
        window_size=args.patch,
        downscaling_factors=(2, 2, 2, 1),
    )

    if args.dp and torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs with DataParallel")
        net = nn.DataParallel(net)

    net = net.to(device)
    criterion = nn.CrossEntropyLoss()

    if args.opt == 'adam':
        optimizer = optim.Adam(net.parameters(), lr=args.lr)
    else:
        optimizer = optim.SGD(net.parameters(), lr=args.lr, momentum=0.9, weight_decay=5e-4)

    scaler = torch.cuda.amp.GradScaler(enabled=not args.noamp and device == 'cuda')
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=args.n_epochs)

    # ✅ Resume logic
    if args.resume:
        checkpoint_path = f'./checkpoint/{args.net}-{args.patch}-ckpt.t7'
        if os.path.exists(checkpoint_path):
            try:
                print(f"Resuming from checkpoint {checkpoint_path}...")
                checkpoint = torch.load(checkpoint_path, map_location=device)
                net.load_state_dict(checkpoint['model'])
                if 'optimizer' in checkpoint and 'scaler' in checkpoint:
                    optimizer.load_state_dict(checkpoint['optimizer'])
                    scaler.load_state_dict(checkpoint['scaler'])
                start_epoch = checkpoint.get('epoch', 0) + 1
                best_acc = checkpoint.get('acc', 0)
                print(f"Resumed at epoch {start_epoch} with best accuracy {best_acc:.2f}%")
            except Exception as e:
                print(f"Failed to load checkpoint: {e}")
                print("Training from scratch instead.")
    else:
        print("No checkpoint found. Training from scratch.")


    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    for epoch in range(start_epoch, args.n_epochs):
        train_loss, train_acc = train(epoch, net, trainloader, criterion, optimizer, scaler, use_amp=not args.noamp, device=device)
        test_loss, test_acc, best_acc = test(epoch, net, testloader, criterion, optimizer, scaler, best_acc, args, device)
        scheduler.step()

        train_losses.append(train_loss)
        test_losses.append(test_loss)
        train_accuracies.append(train_acc)
        test_accuracies.append(test_acc)

        # ✅ Visualize predictions every 10 epochs or at last epoch
        if (epoch + 1) % 2 == 0 or (epoch + 1) == args.n_epochs:
            visualize_predictions(net, testloader, classes, num_samples=5, epoch=epoch + 1, device=device)

    #plot_training(train_losses, test_losses, test_accuracies)
    plot_accuracy(train_accuracies, test_accuracies)
    plot_loss(train_losses, test_losses)




if __name__ == '__main__':
    main()
# Out:
# 100%|██████████| 169M/169M [00:12<00:00, 13.1MB/s]
# Epoch: 0
# <ipython-input-10-678c0e8bf1f5>:228: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=not args.noamp and device == 'cuda')
# <ipython-input-10-678c0e8bf1f5>:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Train Loss: 4.5909 | Train Acc: 1.83%
# Test Loss: 4.3663 | Test Acc: 3.52%
# Saving checkpoint..
#
# Epoch: 1
# Train Loss: 4.4153 | Train Acc: 3.54%
# Test Loss: 4.1163 | Test Acc: 6.28%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_2.png
#
# Epoch: 2
# Train Loss: 4.2652 | Train Acc: 5.37%
# Test Loss: 3.9431 | Test Acc: 8.88%
# Saving checkpoint..
#
# Epoch: 3
# Train Loss: 4.1267 | Train Acc: 7.07%
# Test Loss: 3.7717 | Test Acc: 12.01%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_4.png
#
# Epoch: 4
# Train Loss: 4.0227 | Train Acc: 8.49%
# Test Loss: 3.7011 | Test Acc: 12.62%
# Saving checkpoint..
#
# Epoch: 5
# Train Loss: 3.9254 | Train Acc: 10.13%
# Test Loss: 3.6026 | Test Acc: 14.40%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_6.png
#
# Epoch: 6
# Train Loss: 3.8344 | Train Acc: 11.36%
# Test Loss: 3.4957 | Test Acc: 16.66%
# Saving checkpoint..
#
# Epoch: 7
# Train Loss: 3.7462 | Train Acc: 13.14%
# Test Loss: 3.3762 | Test Acc: 19.21%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_8.png
#
# Epoch: 8
# Train Loss: 3.6523 | Train Acc: 14.62%
# Test Loss: 3.2817 | Test Acc: 20.43%
# Saving checkpoint..
#
# Epoch: 9
# Train Loss: 3.5560 | Train Acc: 16.19%
# Test Loss: 3.1126 | Test Acc: 23.53%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_10.png
#
# Epoch: 10
# Train Loss: 3.4872 | Train Acc: 17.23%
# Test Loss: 3.1156 | Test Acc: 23.90%
# Saving checkpoint..
#
# Epoch: 11
# Train Loss: 3.4236 | Train Acc: 18.66%
# Test Loss: 3.0269 | Test Acc: 25.03%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_12.png
#
# Epoch: 12
# Train Loss: 3.3575 | Train Acc: 19.77%
# Test Loss: 2.9672 | Test Acc: 26.20%
# Saving checkpoint..
#
# Epoch: 13
# Train Loss: 3.2958 | Train Acc: 20.56%
# Test Loss: 2.8736 | Test Acc: 28.25%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_14.png
#
# Epoch: 14
# Train Loss: 3.2461 | Train Acc: 21.85%
# Test Loss: 2.8046 | Test Acc: 29.51%
# Saving checkpoint..
#
# Epoch: 15
# Train Loss: 3.1841 | Train Acc: 22.90%
# Test Loss: 2.7413 | Test Acc: 31.07%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_16.png
#
# Epoch: 16
# Train Loss: 3.1506 | Train Acc: 23.60%
# Test Loss: 2.7048 | Test Acc: 31.47%
# Saving checkpoint..
#
# Epoch: 17
# Train Loss: 3.1085 | Train Acc: 24.05%
# Test Loss: 2.7379 | Test Acc: 31.13%
# Saved sample predictions at: sample_predictions/epoch_18.png
#
# Epoch: 18
# Train Loss: 3.0622 | Train Acc: 24.94%
# Test Loss: 2.6460 | Test Acc: 32.74%
# Saving checkpoint..
#
# Epoch: 19
# Train Loss: 3.0231 | Train Acc: 25.83%
# Test Loss: 2.5953 | Test Acc: 34.08%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_20.png
#
# Epoch: 20
# Train Loss: 3.0002 | Train Acc: 26.22%
# Test Loss: 2.5762 | Test Acc: 34.16%
# Saving checkpoint..
#
# Epoch: 21
# Train Loss: 2.9562 | Train Acc: 26.96%
# Test Loss: 2.5269 | Test Acc: 35.71%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_22.png
#
# Epoch: 22
# Train Loss: 2.9309 | Train Acc: 27.61%
# Test Loss: 2.5392 | Test Acc: 35.15%
#
# Epoch: 23
# Train Loss: 2.8879 | Train Acc: 28.70%
# Test Loss: 2.5430 | Test Acc: 34.81%
# Saved sample predictions at: sample_predictions/epoch_24.png
#
# Epoch: 24
# Train Loss: 2.8641 | Train Acc: 28.82%
# Test Loss: 2.4666 | Test Acc: 37.02%
# Saving checkpoint..
#
# Epoch: 25
# Train Loss: 2.8457 | Train Acc: 29.37%
# Test Loss: 2.4400 | Test Acc: 36.78%
# Saved sample predictions at: sample_predictions/epoch_26.png
#
# Epoch: 26
# Train Loss: 2.7999 | Train Acc: 30.38%
# Test Loss: 2.3996 | Test Acc: 38.21%
# Saving checkpoint..
#
# Epoch: 27
# Train Loss: 2.7749 | Train Acc: 30.68%
# Test Loss: 2.3538 | Test Acc: 39.34%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_28.png
#
# Epoch: 28
# Train Loss: 2.7445 | Train Acc: 31.24%
# Test Loss: 2.3564 | Test Acc: 39.68%
# Saving checkpoint..
#
# Epoch: 29
# Train Loss: 2.7245 | Train Acc: 31.78%
# Test Loss: 2.3697 | Test Acc: 39.15%
# Saved sample predictions at: sample_predictions/epoch_30.png
#
# Epoch: 30
# Train Loss: 2.6944 | Train Acc: 32.20%
# Test Loss: 2.3144 | Test Acc: 39.82%
# Saving checkpoint..
#
# Epoch: 31
# Train Loss: 2.6757 | Train Acc: 32.75%
# Test Loss: 2.2824 | Test Acc: 40.82%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_32.png
#
# Epoch: 32
# Train Loss: 2.6390 | Train Acc: 33.52%
# Test Loss: 2.2537 | Test Acc: 41.20%
# Saving checkpoint..
#
# Epoch: 33
# Train Loss: 2.6320 | Train Acc: 33.69%
# Test Loss: 2.2705 | Test Acc: 41.26%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_34.png
#
# Epoch: 34
# Train Loss: 2.6056 | Train Acc: 34.04%
# Test Loss: 2.2681 | Test Acc: 41.09%
#
# Epoch: 35
# Train Loss: 2.5835 | Train Acc: 34.48%
# Test Loss: 2.2410 | Test Acc: 41.80%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_36.png
#
# Epoch: 36
# Train Loss: 2.5611 | Train Acc: 34.87%
# Test Loss: 2.1654 | Test Acc: 43.18%
# Saving checkpoint..
#
# Epoch: 37
# Train Loss: 2.5447 | Train Acc: 35.28%
# Test Loss: 2.1857 | Test Acc: 42.74%
# Saved sample predictions at: sample_predictions/epoch_38.png
#
# Epoch: 38
# Train Loss: 2.5260 | Train Acc: 35.81%
# Test Loss: 2.1489 | Test Acc: 43.79%
# Saving checkpoint..
#
# Epoch: 39
# Train Loss: 2.5146 | Train Acc: 35.98%
# Test Loss: 2.1649 | Test Acc: 43.46%
# Saved sample predictions at: sample_predictions/epoch_40.png
#
# Epoch: 40
# Train Loss: 2.4840 | Train Acc: 36.39%
# Test Loss: 2.1286 | Test Acc: 44.27%
# Saving checkpoint..
#
# Epoch: 41
# Train Loss: 2.4662 | Train Acc: 36.88%
# Test Loss: 2.1005 | Test Acc: 44.78%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_42.png
#
# Epoch: 42
# Train Loss: 2.4344 | Train Acc: 37.66%
# Test Loss: 2.1250 | Test Acc: 44.24%
#
# Epoch: 43
# Train Loss: 2.4243 | Train Acc: 38.17%
# Test Loss: 2.1338 | Test Acc: 44.06%
# Saved sample predictions at: sample_predictions/epoch_44.png
#
# Epoch: 44
# Train Loss: 2.4043 | Train Acc: 38.29%
# Test Loss: 2.1078 | Test Acc: 44.67%
#
# Epoch: 45
# Train Loss: 2.3920 | Train Acc: 38.75%
# Test Loss: 2.0772 | Test Acc: 45.33%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_46.png
#
# Epoch: 46
# Train Loss: 2.3668 | Train Acc: 38.97%
# Test Loss: 2.0481 | Test Acc: 46.07%
# Saving checkpoint..
#
# Epoch: 47
# Train Loss: 2.3540 | Train Acc: 39.24%
# Test Loss: 2.0310 | Test Acc: 46.41%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_48.png
#
# Epoch: 48
# Train Loss: 2.3323 | Train Acc: 39.94%
# Test Loss: 2.0450 | Test Acc: 46.33%
#
# Epoch: 49
# Train Loss: 2.3117 | Train Acc: 40.16%
# Test Loss: 2.0306 | Test Acc: 46.79%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_50.png
#
# Epoch: 50
# Train Loss: 2.3007 | Train Acc: 40.64%
# Test Loss: 2.0304 | Test Acc: 46.42%
#
# Epoch: 51
# Train Loss: 2.2846 | Train Acc: 40.70%
# Test Loss: 2.0416 | Test Acc: 46.63%
# Saved sample predictions at: sample_predictions/epoch_52.png
#
# Epoch: 52
# Train Loss: 2.2601 | Train Acc: 41.25%
# Test Loss: 1.9882 | Test Acc: 47.87%
# Saving checkpoint..
#
# Epoch: 53
# Train Loss: 2.2550 | Train Acc: 41.37%
# Test Loss: 1.9646 | Test Acc: 47.85%
# Saved sample predictions at: sample_predictions/epoch_54.png
#
# Epoch: 54
# Train Loss: 2.2243 | Train Acc: 42.07%
# Test Loss: 1.9573 | Test Acc: 48.40%
# Saving checkpoint..
#
# Epoch: 55
# Train Loss: 2.2184 | Train Acc: 42.34%
# Test Loss: 1.9528 | Test Acc: 48.23%
# Saved sample predictions at: sample_predictions/epoch_56.png
#
# Epoch: 56
# Train Loss: 2.1932 | Train Acc: 42.81%
# Test Loss: 1.9877 | Test Acc: 47.89%
#
# Epoch: 57
# Train Loss: 2.1796 | Train Acc: 43.10%
# Test Loss: 1.9581 | Test Acc: 48.41%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_58.png
#
# Epoch: 58
# Train Loss: 2.1676 | Train Acc: 43.19%
# Test Loss: 1.9329 | Test Acc: 48.58%
# Saving checkpoint..
#
# Epoch: 59
# Train Loss: 2.1553 | Train Acc: 43.53%
# Test Loss: 1.9194 | Test Acc: 49.60%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_60.png
#
# Epoch: 60
# Train Loss: 2.1311 | Train Acc: 44.20%
# Test Loss: 1.9346 | Test Acc: 48.48%
#
# Epoch: 61
# Train Loss: 2.1106 | Train Acc: 44.56%
# Test Loss: 1.9105 | Test Acc: 48.90%
# Saved sample predictions at: sample_predictions/epoch_62.png
#
# Epoch: 62
# Train Loss: 2.1011 | Train Acc: 44.72%
# Test Loss: 1.8998 | Test Acc: 49.60%
#
# Epoch: 63
# Train Loss: 2.0830 | Train Acc: 45.10%
# Test Loss: 1.9089 | Test Acc: 49.90%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_64.png
#
# Epoch: 64
# Train Loss: 2.0651 | Train Acc: 45.23%
# Test Loss: 1.8983 | Test Acc: 49.66%
#
# Epoch: 65
# Train Loss: 2.0516 | Train Acc: 45.78%
# Test Loss: 1.9280 | Test Acc: 49.16%
# Saved sample predictions at: sample_predictions/epoch_66.png
#
# Epoch: 66
# Train Loss: 2.0368 | Train Acc: 46.21%
# Test Loss: 1.8787 | Test Acc: 50.02%
# Saving checkpoint..
#
# Epoch: 67
# Train Loss: 2.0141 | Train Acc: 46.74%
# Test Loss: 1.8338 | Test Acc: 51.54%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_68.png
#
# Epoch: 68
# Train Loss: 2.0034 | Train Acc: 47.10%
# Test Loss: 1.8260 | Test Acc: 51.24%
#
# Epoch: 69
# Train Loss: 1.9847 | Train Acc: 47.25%
# Test Loss: 1.8256 | Test Acc: 51.51%
# Saved sample predictions at: sample_predictions/epoch_70.png
#
# Epoch: 70
# Train Loss: 1.9650 | Train Acc: 47.68%
# Test Loss: 1.8580 | Test Acc: 50.83%
#
# Epoch: 71
# Train Loss: 1.9478 | Train Acc: 47.92%
# Test Loss: 1.8442 | Test Acc: 51.17%
# Saved sample predictions at: sample_predictions/epoch_72.png
#
# Epoch: 72
# Train Loss: 1.9411 | Train Acc: 48.30%
# Test Loss: 1.8562 | Test Acc: 50.46%
#
# Epoch: 73
# Train Loss: 1.9224 | Train Acc: 48.83%
# Test Loss: 1.7993 | Test Acc: 51.99%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_74.png
#
# Epoch: 74
# Train Loss: 1.8979 | Train Acc: 49.04%
# Test Loss: 1.8384 | Test Acc: 51.77%
#
# Epoch: 75
# Train Loss: 1.8951 | Train Acc: 49.46%
# Test Loss: 1.8120 | Test Acc: 51.94%
# Saved sample predictions at: sample_predictions/epoch_76.png
#
# Epoch: 76
# Train Loss: 1.8783 | Train Acc: 49.83%
# Test Loss: 1.7944 | Test Acc: 52.97%
# Saving checkpoint..
#
# Epoch: 77
# Train Loss: 1.8633 | Train Acc: 49.84%
# Test Loss: 1.8073 | Test Acc: 52.05%
# Saved sample predictions at: sample_predictions/epoch_78.png
#
# Epoch: 78
# Train Loss: 1.8467 | Train Acc: 50.46%
# Test Loss: 1.7918 | Test Acc: 52.66%
#
# Epoch: 79
# Train Loss: 1.8376 | Train Acc: 50.77%
# Test Loss: 1.7398 | Test Acc: 54.09%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_80.png
#
# Epoch: 80
# Train Loss: 1.8181 | Train Acc: 51.17%
# Test Loss: 1.7491 | Test Acc: 53.34%
#
# Epoch: 81
# Train Loss: 1.8006 | Train Acc: 51.46%
# Test Loss: 1.7706 | Test Acc: 52.29%
# Saved sample predictions at: sample_predictions/epoch_82.png
#
# Epoch: 82
# Train Loss: 1.7894 | Train Acc: 51.72%
# Test Loss: 1.7845 | Test Acc: 53.00%
#
# Epoch: 83
# Train Loss: 1.7762 | Train Acc: 52.00%
# Test Loss: 1.7454 | Test Acc: 53.27%
# Saved sample predictions at: sample_predictions/epoch_84.png
#
# Epoch: 84
# Train Loss: 1.7573 | Train Acc: 52.44%
# Test Loss: 1.7479 | Test Acc: 53.39%
#
# Epoch: 85
# Train Loss: 1.7403 | Train Acc: 52.89%
# Test Loss: 1.7291 | Test Acc: 53.90%
# Saved sample predictions at: sample_predictions/epoch_86.png
#
# Epoch: 86
# Train Loss: 1.7269 | Train Acc: 53.42%
# Test Loss: 1.7448 | Test Acc: 53.70%
#
# Epoch: 87
# Train Loss: 1.7246 | Train Acc: 53.43%
# Test Loss: 1.7409 | Test Acc: 53.24%
# Saved sample predictions at: sample_predictions/epoch_88.png
#
# Epoch: 88
# Train Loss: 1.6984 | Train Acc: 54.00%
# Test Loss: 1.7490 | Test Acc: 54.04%
#
# Epoch: 89
# Train Loss: 1.6808 | Train Acc: 54.15%
# Test Loss: 1.7187 | Test Acc: 54.41%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_90.png
#
# Epoch: 90
# Train Loss: 1.6704 | Train Acc: 54.59%
# Test Loss: 1.7486 | Test Acc: 53.77%
#
# Epoch: 91
# Train Loss: 1.6474 | Train Acc: 55.22%
# Test Loss: 1.7317 | Test Acc: 54.31%
# Saved sample predictions at: sample_predictions/epoch_92.png
#
# Epoch: 92
# Train Loss: 1.6418 | Train Acc: 55.29%
# Test Loss: 1.7134 | Test Acc: 55.09%
# Saving checkpoint..
#
# Epoch: 93
# Train Loss: 1.6261 | Train Acc: 55.61%
# Test Loss: 1.7119 | Test Acc: 54.48%
# Saved sample predictions at: sample_predictions/epoch_94.png
#
# Epoch: 94
# Train Loss: 1.6070 | Train Acc: 55.95%
# Test Loss: 1.7075 | Test Acc: 55.46%
# Saving checkpoint..
#
# Epoch: 95
# Train Loss: 1.5885 | Train Acc: 56.56%
# Test Loss: 1.6977 | Test Acc: 55.23%
# Saved sample predictions at: sample_predictions/epoch_96.png
#
# Epoch: 96
# Train Loss: 1.5762 | Train Acc: 56.82%
# Test Loss: 1.6948 | Test Acc: 55.40%
#
# Epoch: 97
# Train Loss: 1.5654 | Train Acc: 57.31%
# Test Loss: 1.6897 | Test Acc: 55.78%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_98.png
#
# Epoch: 98
# Train Loss: 1.5560 | Train Acc: 57.30%
# Test Loss: 1.6963 | Test Acc: 55.48%
#
# Epoch: 99
# Train Loss: 1.5268 | Train Acc: 57.91%
# Test Loss: 1.6999 | Test Acc: 55.90%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_100.png
#
# Epoch: 100
# Train Loss: 1.5245 | Train Acc: 58.17%
# Test Loss: 1.7073 | Test Acc: 55.24%
#
# Epoch: 101
# Train Loss: 1.5035 | Train Acc: 58.74%
# Test Loss: 1.7259 | Test Acc: 55.01%
# Saved sample predictions at: sample_predictions/epoch_102.png
#
# Epoch: 102
# Train Loss: 1.4981 | Train Acc: 58.86%
# Test Loss: 1.6915 | Test Acc: 56.23%
# Saving checkpoint..
#
# Epoch: 103
# Train Loss: 1.4730 | Train Acc: 59.49%
# Test Loss: 1.6955 | Test Acc: 55.30%
# Saved sample predictions at: sample_predictions/epoch_104.png
#
# Epoch: 104
# Train Loss: 1.4662 | Train Acc: 59.43%
# Test Loss: 1.7018 | Test Acc: 55.76%
#
# Epoch: 105
# Train Loss: 1.4612 | Train Acc: 59.70%
# Test Loss: 1.6856 | Test Acc: 55.91%
# Saved sample predictions at: sample_predictions/epoch_106.png
#
# Epoch: 106
# Train Loss: 1.4432 | Train Acc: 60.17%
# Test Loss: 1.6703 | Test Acc: 56.63%
# Saving checkpoint..
#
# Epoch: 107
# Train Loss: 1.4231 | Train Acc: 60.57%
# Test Loss: 1.7188 | Test Acc: 55.78%
# Saved sample predictions at: sample_predictions/epoch_108.png
#
# Epoch: 108
# Train Loss: 1.4172 | Train Acc: 60.75%
# Test Loss: 1.6798 | Test Acc: 56.85%
# Saving checkpoint..
#
# Epoch: 109
# Train Loss: 1.4008 | Train Acc: 61.27%
# Test Loss: 1.6666 | Test Acc: 56.55%
# Saved sample predictions at: sample_predictions/epoch_110.png
#
# Epoch: 110
# Train Loss: 1.3869 | Train Acc: 61.61%
# Test Loss: 1.6861 | Test Acc: 56.32%
#
# Epoch: 111
# Train Loss: 1.3703 | Train Acc: 61.79%
# Test Loss: 1.6694 | Test Acc: 56.75%
# Saved sample predictions at: sample_predictions/epoch_112.png
#
# Epoch: 112
# Train Loss: 1.3624 | Train Acc: 62.18%
# Test Loss: 1.6855 | Test Acc: 56.80%
#
# Epoch: 113
# Train Loss: 1.3553 | Train Acc: 62.41%
# Test Loss: 1.6622 | Test Acc: 57.11%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_114.png
#
# Epoch: 114
# Train Loss: 1.3362 | Train Acc: 62.95%
# Test Loss: 1.6754 | Test Acc: 56.54%
#
# Epoch: 115
# Train Loss: 1.3394 | Train Acc: 62.86%
# Test Loss: 1.6712 | Test Acc: 57.26%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_116.png
#
# Epoch: 116
# Train Loss: 1.3107 | Train Acc: 63.71%
# Test Loss: 1.6748 | Test Acc: 56.97%
#
# Epoch: 117
# Train Loss: 1.3010 | Train Acc: 63.71%
# Test Loss: 1.6707 | Test Acc: 56.76%
# Saved sample predictions at: sample_predictions/epoch_118.png
#
# Epoch: 118
# Train Loss: 1.2814 | Train Acc: 64.15%
# Test Loss: 1.6787 | Test Acc: 56.90%
#
# Epoch: 119
# Train Loss: 1.2749 | Train Acc: 64.28%
# Test Loss: 1.6844 | Test Acc: 56.75%
# Saved sample predictions at: sample_predictions/epoch_120.png
#
# Epoch: 120
# Train Loss: 1.2737 | Train Acc: 64.51%
# Test Loss: 1.6751 | Test Acc: 57.65%
# Saving checkpoint..
#
# Epoch: 121
# Train Loss: 1.2576 | Train Acc: 65.13%
# Test Loss: 1.6774 | Test Acc: 56.68%
# Saved sample predictions at: sample_predictions/epoch_122.png
#
# Epoch: 122
# Train Loss: 1.2315 | Train Acc: 65.60%
# Test Loss: 1.6747 | Test Acc: 57.49%
#
# Epoch: 123
# Train Loss: 1.2265 | Train Acc: 65.84%
# Test Loss: 1.6766 | Test Acc: 57.64%
# Saved sample predictions at: sample_predictions/epoch_124.png
#
# Epoch: 124
# Train Loss: 1.2160 | Train Acc: 65.91%
# Test Loss: 1.6654 | Test Acc: 57.43%
#
# Epoch: 125
# Train Loss: 1.2044 | Train Acc: 66.18%
# Test Loss: 1.6778 | Test Acc: 57.35%
# Saved sample predictions at: sample_predictions/epoch_126.png
#
# Epoch: 126
# Train Loss: 1.1898 | Train Acc: 66.77%
# Test Loss: 1.6740 | Test Acc: 57.43%
#
# Epoch: 127
# Train Loss: 1.1885 | Train Acc: 66.62%
# Test Loss: 1.7079 | Test Acc: 56.76%
# Saved sample predictions at: sample_predictions/epoch_128.png
#
# Epoch: 128
# Train Loss: 1.1595 | Train Acc: 67.64%
# Test Loss: 1.6571 | Test Acc: 57.63%
#
# Epoch: 129
# Train Loss: 1.1668 | Train Acc: 67.26%
# Test Loss: 1.6756 | Test Acc: 57.57%
# Saved sample predictions at: sample_predictions/epoch_130.png
#
# Epoch: 130
# Train Loss: 1.1430 | Train Acc: 68.03%
# Test Loss: 1.6616 | Test Acc: 58.09%
# Saving checkpoint..
#
# Epoch: 131
# Train Loss: 1.1323 | Train Acc: 68.33%
# Test Loss: 1.6920 | Test Acc: 57.68%
# Saved sample predictions at: sample_predictions/epoch_132.png
#
# Epoch: 132
# Train Loss: 1.1365 | Train Acc: 68.22%
# Test Loss: 1.6832 | Test Acc: 57.76%
#
# Epoch: 133
# Train Loss: 1.1216 | Train Acc: 68.47%
# Test Loss: 1.6819 | Test Acc: 57.83%
# Saved sample predictions at: sample_predictions/epoch_134.png
#
# Epoch: 134
# Train Loss: 1.1043 | Train Acc: 69.09%
# Test Loss: 1.6944 | Test Acc: 57.87%
#
# Epoch: 135
# Train Loss: 1.0974 | Train Acc: 69.21%
# Test Loss: 1.6916 | Test Acc: 57.61%
# Saved sample predictions at: sample_predictions/epoch_136.png
#
# Epoch: 136
# Train Loss: 1.0828 | Train Acc: 69.65%
# Test Loss: 1.7030 | Test Acc: 57.32%
#
# Epoch: 137
# Train Loss: 1.0741 | Train Acc: 70.25%
# Test Loss: 1.7001 | Test Acc: 57.63%
# Saved sample predictions at: sample_predictions/epoch_138.png
#
# Epoch: 138
# Train Loss: 1.0744 | Train Acc: 69.85%
# Test Loss: 1.6802 | Test Acc: 58.19%
# Saving checkpoint..
#
# Epoch: 139
# Train Loss: 1.0580 | Train Acc: 70.33%
# Test Loss: 1.6788 | Test Acc: 58.08%
# Saved sample predictions at: sample_predictions/epoch_140.png
#
# Epoch: 140
# Train Loss: 1.0512 | Train Acc: 70.54%
# Test Loss: 1.6782 | Test Acc: 58.36%
# Saving checkpoint..
#
# Epoch: 141
# Train Loss: 1.0401 | Train Acc: 70.87%
# Test Loss: 1.7036 | Test Acc: 57.76%
# Saved sample predictions at: sample_predictions/epoch_142.png
#
# Epoch: 142
# Train Loss: 1.0370 | Train Acc: 70.73%
# Test Loss: 1.7045 | Test Acc: 57.80%
#
# Epoch: 143
# Train Loss: 1.0278 | Train Acc: 71.17%
# Test Loss: 1.6668 | Test Acc: 58.77%
# Saving checkpoint..
# Saved sample predictions at: sample_predictions/epoch_144.png
#
# Epoch: 144
# Train Loss: 1.0144 | Train Acc: 71.56%
# Test Loss: 1.7097 | Test Acc: 57.94%
#
# Epoch: 145
# Train Loss: 1.0061 | Train Acc: 71.79%
# Test Loss: 1.6841 | Test Acc: 58.62%
# Saved sample predictions at: sample_predictions/epoch_146.png
#
# Epoch: 146
# Train Loss: 0.9943 | Train Acc: 72.12%
# Test Loss: 1.6794 | Test Acc: 58.42%
#
# Epoch: 147
# Train Loss: 0.9983 | Train Acc: 72.05%
# Test Loss: 1.6871 | Test Acc: 58.42%
# Saved sample predictions at: sample_predictions/epoch_148.png
#
# Epoch: 148
# Train Loss: 0.9897 | Train Acc: 72.21%
# Test Loss: 1.6824 | Test Acc: 58.59%
#
# Epoch: 149
# Train Loss: 0.9657 | Train Acc: 72.87%
# Test Loss: 1.6892 | Test Acc: 58.49%
# Saved sample predictions at: sample_predictions/epoch_150.png
#
# Epoch: 150
# Train Loss: 0.9611 | Train Acc: 73.01%
# Test Loss: 1.6928 | Test Acc: 58.59%
#
# Epoch: 151
# Train Loss: 0.9561 | Train Acc: 73.16%
# Test Loss: 1.6937 | Test Acc: 58.70%
# Saved sample predictions at: sample_predictions/epoch_152.png
#
# Epoch: 152
# Train Loss: 0.9417 | Train Acc: 73.73%
# Test Loss: 1.6886 | Test Acc: 58.69%
#
# Epoch: 153
# Train Loss: 0.9421 | Train Acc: 73.59%
# Test Loss: 1.6886 | Test Acc: 58.73%
# Saved sample predictions at: sample_predictions/epoch_154.png
#
# Epoch: 154
# Train Loss: 0.9319 | Train Acc: 73.73%
# Test Loss: 1.6760 | Test Acc: 59.30%
# Saving checkpoint..
#
# Epoch: 155
# Train Loss: 0.9323 | Train Acc: 73.71%
# Test Loss: 1.6850 | Test Acc: 58.87%
# Saved sample predictions at: sample_predictions/epoch_156.png
#
# Epoch: 156
# Train Loss: 0.9253 | Train Acc: 73.98%
# Test Loss: 1.6861 | Test Acc: 58.78%
#
# Epoch: 157
# Train Loss: 0.9313 | Train Acc: 74.07%
# Test Loss: 1.7072 | Test Acc: 58.53%
# Saved sample predictions at: sample_predictions/epoch_158.png
#
# Epoch: 158
# Train Loss: 0.9134 | Train Acc: 74.39%
# Test Loss: 1.6937 | Test Acc: 59.29%
#
# Epoch: 159
# Train Loss: 0.9083 | Train Acc: 74.64%
# Test Loss: 1.6903 | Test Acc: 58.87%
# Saved sample predictions at: sample_predictions/epoch_160.png
#
# Epoch: 160
# Train Loss: 0.8994 | Train Acc: 74.75%
# Test Loss: 1.7011 | Test Acc: 58.77%
#
# Epoch: 161
# Train Loss: 0.8978 | Train Acc: 74.96%
# Test Loss: 1.6904 | Test Acc: 59.19%
# Saved sample predictions at: sample_predictions/epoch_162.png
#
# Epoch: 162
# Train Loss: 0.8854 | Train Acc: 75.04%
# Test Loss: 1.6920 | Test Acc: 58.80%
#
# Epoch: 163
# Train Loss: 0.8818 | Train Acc: 75.13%
# Test Loss: 1.6947 | Test Acc: 58.75%
# Saved sample predictions at: sample_predictions/epoch_164.png
#
# Epoch: 164
# Train Loss: 0.8858 | Train Acc: 74.90%
# Test Loss: 1.6938 | Test Acc: 59.07%
#
# Epoch: 165
# Train Loss: 0.8792 | Train Acc: 75.36%
# Test Loss: 1.7030 | Test Acc: 59.14%
# Saved sample predictions at: sample_predictions/epoch_166.png
#
# Epoch: 166
# Train Loss: 0.8758 | Train Acc: 75.29%
# Test Loss: 1.7041 | Test Acc: 58.74%
#
# Epoch: 167
# Train Loss: 0.8686 | Train Acc: 75.67%
# Test Loss: 1.6936 | Test Acc: 59.03%
# Saved sample predictions at: sample_predictions/epoch_168.png
#
# Epoch: 168
# Train Loss: 0.8590 | Train Acc: 76.04%
# Test Loss: 1.6999 | Test Acc: 59.10%
#
# Epoch: 169
# Train Loss: 0.8641 | Train Acc: 75.98%
# Test Loss: 1.6894 | Test Acc: 59.27%
# Saved sample predictions at: sample_predictions/epoch_170.png
#
# Epoch: 170
# Train Loss: 0.8557 | Train Acc: 76.13%
# Test Loss: 1.6941 | Test Acc: 59.04%
#
# Epoch: 171
# Train Loss: 0.8558 | Train Acc: 76.17%
# Test Loss: 1.6973 | Test Acc: 58.93%
# Saved sample predictions at: sample_predictions/epoch_172.png
#
# Epoch: 172
# Train Loss: 0.8422 | Train Acc: 76.55%
# Test Loss: 1.6895 | Test Acc: 59.39%
# Saving checkpoint..
#
# Epoch: 173
# Train Loss: 0.8527 | Train Acc: 76.16%
# Test Loss: 1.6900 | Test Acc: 59.34%
# Saved sample predictions at: sample_predictions/epoch_174.png
#
# Epoch: 174
# Train Loss: 0.8432 | Train Acc: 76.40%
# Test Loss: 1.6920 | Test Acc: 59.29%
#
# Epoch: 175
# Train Loss: 0.8424 | Train Acc: 76.43%
# Test Loss: 1.6942 | Test Acc: 59.15%
# Saved sample predictions at: sample_predictions/epoch_176.png
#
# Epoch: 176
# Train Loss: 0.8442 | Train Acc: 76.54%
# Test Loss: 1.6944 | Test Acc: 59.21%
#
# Epoch: 177
# Train Loss: 0.8278 | Train Acc: 76.84%
# Test Loss: 1.6893 | Test Acc: 59.22%
# Saved sample predictions at: sample_predictions/epoch_178.png
#
# Epoch: 178
# Train Loss: 0.8413 | Train Acc: 76.61%
# Test Loss: 1.7015 | Test Acc: 59.39%
#
# Epoch: 179
# Train Loss: 0.8332 | Train Acc: 76.56%
# Test Loss: 1.6972 | Test Acc: 59.16%
# Saved sample predictions at: sample_predictions/epoch_180.png
#
# Epoch: 180
# Train Loss: 0.8289 | Train Acc: 76.68%
# Test Loss: 1.6902 | Test Acc: 59.42%
# Saving checkpoint..
#
# Epoch: 181
# Train Loss: 0.8227 | Train Acc: 76.88%
# Test Loss: 1.6925 | Test Acc: 59.34%
# Saved sample predictions at: sample_predictions/epoch_182.png
#
# Epoch: 182
# Train Loss: 0.8369 | Train Acc: 76.56%
# Test Loss: 1.6947 | Test Acc: 59.24%
#
# Epoch: 183
# Train Loss: 0.8246 | Train Acc: 76.75%
# Test Loss: 1.6976 | Test Acc: 59.23%
# Saved sample predictions at: sample_predictions/epoch_184.png
#
# Epoch: 184
# Train Loss: 0.8212 | Train Acc: 77.22%
# Test Loss: 1.6955 | Test Acc: 59.24%
#
# Epoch: 185
# Train Loss: 0.8103 | Train Acc: 77.60%
# Test Loss: 1.6977 | Test Acc: 59.31%
# Saved sample predictions at: sample_predictions/epoch_186.png
#
# Epoch: 186
# Train Loss: 0.8147 | Train Acc: 77.23%
# Test Loss: 1.6976 | Test Acc: 59.37%
#
# Epoch: 187
# Train Loss: 0.8142 | Train Acc: 77.34%
# Test Loss: 1.7001 | Test Acc: 59.14%
# Saved sample predictions at: sample_predictions/epoch_188.png
#
# Epoch: 188
# Train Loss: 0.8172 | Train Acc: 77.26%
# Test Loss: 1.6954 | Test Acc: 59.28%
#
# Epoch: 189
# Train Loss: 0.8142 | Train Acc: 77.51%
# Test Loss: 1.6947 | Test Acc: 59.20%
# Saved sample predictions at: sample_predictions/epoch_190.png
#
# Epoch: 190
# Train Loss: 0.8200 | Train Acc: 77.19%
# Test Loss: 1.6929 | Test Acc: 59.38%
#
# Epoch: 191
# Train Loss: 0.8212 | Train Acc: 77.12%
# Test Loss: 1.6939 | Test Acc: 59.38%
# Saved sample predictions at: sample_predictions/epoch_192.png
#
# Epoch: 192
# Train Loss: 0.8074 | Train Acc: 77.38%
# Test Loss: 1.6925 | Test Acc: 59.40%
#
# Epoch: 193
# Train Loss: 0.8075 | Train Acc: 77.53%
# Test Loss: 1.6923 | Test Acc: 59.37%
# Saved sample predictions at: sample_predictions/epoch_194.png
#
# Epoch: 194
# Train Loss: 0.8049 | Train Acc: 77.56%
# Test Loss: 1.6946 | Test Acc: 59.23%
#
# Epoch: 195
# Train Loss: 0.8149 | Train Acc: 77.32%
# Test Loss: 1.6947 | Test Acc: 59.30%
# Saved sample predictions at: sample_predictions/epoch_196.png
#
# Epoch: 196
# Train Loss: 0.8029 | Train Acc: 77.60%
# Test Loss: 1.6943 | Test Acc: 59.32%
#
# Epoch: 197
# Train Loss: 0.8183 | Train Acc: 77.19%
# Test Loss: 1.6946 | Test Acc: 59.29%
# Saved sample predictions at: sample_predictions/epoch_198.png
#
# Epoch: 198
# Train Loss: 0.8074 | Train Acc: 77.40%
# Test Loss: 1.6946 | Test Acc: 59.30%
#
# Epoch: 199
# Train Loss: 0.8117 | Train Acc: 77.23%
# Test Loss: 1.6946 | Test Acc: 59.30%
# Saved sample predictions at: sample_predictions/epoch_200.png

# %%
import os

print(os.path.exists('./checkpoint/swin-4-ckpt.t7'))
print(os.path.getsize('./checkpoint/swin-4-ckpt.t7'))
# Out:
# True
# 25165824

# %%
def plot_training(train_losses, test_losses, test_accuracies):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, test_losses, label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Train & Test Loss By Epoch')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracies, label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.title('Test Accuracy By Epoch')
    plt.legend()

    plt.tight_layout()
    plt.show()
